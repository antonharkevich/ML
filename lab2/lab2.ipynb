# %%
#all necessary imports
from PIL import Image
import io
import pathlib
from pathlib import Path
import imagehash
import shutil
import os
import numpy as np
from numpy import asarray
import splitfolders
from sklearn.linear_model import LogisticRegression
import matplotlib.pylab as plt
import tensorflow as tf
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\Users\AntonHarkevich\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#set max train images amount, validation images amount, test images amount
train_size = 200000
validation_size = 10000
test_size = 19000

#set of all letters in dataset
letter_set = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

#dict for convert letters to numbers
letter_dict = {
    'A': 0,
    'B': 1,
    'C': 2,
    'D': 3,
    'E': 4,
    'F': 5,
    'G': 6,
    'H': 7,
    'I': 8,
    'J': 9
}

#scores dictionary for plot 
scores_test = {}
scores_val  = {}



#test data
x_test = []

#test labels
y_test = []

print('test data')

i = 0

for letter in letter_set:
    folder = Path(f"./for_train_all_{train_size}_nw/test/{letter}_new")
    if folder.is_dir():
        for file in folder.iterdir():
            #use the asarray function to convert an image to array of pixel values based on the color of the pixel  
            x_test.append(asarray(Image.open(file)))

            #add letter label number
            y_test.append(letter_dict[letter])
            
            i += 1
                
            if(i % 1000 == 0):
                print(i)
            
            
#validation data
x_valid = []

#validation labels
y_valid = []

print('validation data')

for letter in letter_set:
    folder = Path(f"./for_train_all_{train_size}_nw/val/{letter}_new")
    if folder.is_dir():
        for file in folder.iterdir():
            #use the asarray function to convert an image to array of pixel values based on the color of the pixel  
            x_valid.append(asarray(Image.open(file)))

            #add letter label number
            y_valid.append(letter_dict[letter])
            
            i += 1
                
            if(i % 1000 == 0):
                print(i)
                
#convert test image data and labels to numpy arrays and normalize data             
x_test = np.array(x_test) / 255.0
y_test = np.array(y_test)     

#convert validation image data and labels to numpy arrays and normalize data 
x_valid = np.array(x_valid) / 255.0
y_valid = np.array(y_valid)
# Out:
# test data
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# validation data
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000

# %%
#each measure for plot 
for measure in ([50,100,1000,50000,200000]):  

    
    #train data
    x_train = [0] * measure
    #train labels
    y_train = []
    

    i = 0
        
    for letter in letter_set:
        folder = Path(f"./for_train_all_{train_size}_nw/train/{letter}_new")

        if folder.is_dir():
            for file in folder.iterdir():
                #use the asarray function to convert an image to array of pixel values based on the color of the pixel  
                x_train[i] = asarray(Image.open(file))
                
                #add letter label number
                y_train.append(letter_dict[letter])
                
                i += 1
                
                if(i % 1000 == 0):
                    print(i)
                
                if(i % (measure//10) == 0):
                    break
                    
    #convert train image data and labels to numpy arrays and normalize data                 
    x_train = np.array(x_train) / 255.0
    y_train = np.array(y_train)
    
    print('start fit')
    #prediction model
    #Flatten layer to reshape image dimensions to a single dimension
    #Dense layer of 128 neurons, 128 neurons and 64 neurons the second, third and fourth layers
    #Dense layer with 10 neurons as number of letters
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(128, activation=tf.nn.relu),
        keras.layers.Dense(128, activation=tf.nn.relu),
        keras.layers.Dense(64, activation=tf.nn.relu),
        keras.layers.Dense(10, activation=tf.nn.softmax)
    ])
    
    #compile model with SGD optimizer, sparse_categorical_crossentropy loss and accuracy metric
    model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    
    #fit model with 40 epochs
    model.fit(x_train, y_train, epochs=40)
    
    print('end fit')
    
    #calc test loss and accuracy
    test_loss, test_acc = model.evaluate(x_test, y_test)
    print(f"Test score for measure {measure} loss: {test_loss}")
    print(f"Test score for measure {measure} accuracy: {test_acc}")
    
    
    scores_test[measure] = test_acc
                    
    #calc validation loss and accuracy
    valid_loss, valid_acc = model.evaluate(x_valid, y_valid)
    
    print(f"Validation score for measure {measure} loss: {valid_loss}")
    print(f"Validation score for measure {measure} accuracy: {valid_acc}")
    
    scores_val[measure] = valid_acc
    
    model.save(f"lab_2_1_{measure}.h5")
# Out:
# start fit
# Epoch 1/40
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3551 - accuracy: 0.1200
# Epoch 2/40
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3142 - accuracy: 0.1000
# Epoch 3/40
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2741 - accuracy: 0.1200
# Epoch 4/40
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2392 - accuracy: 0.1800
# Epoch 5/40
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2127 - accuracy: 0.1800
# Epoch 6/40
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1746 - accuracy: 0.2200
# Epoch 7/40
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1468 - accuracy: 0.2400
# Epoch 8/40
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1229 - accuracy: 0.2800
# Epoch 9/40
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0970 - accuracy: 0.3000
# Epoch 10/40
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0734 - accuracy: 0.3600
# Epoch 11/40
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0514 - accuracy: 0.4000
# Epoch 12/40
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0284 - accuracy: 0.4200
# Epoch 13/40
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0061 - accuracy: 0.4400
# Epoch 14/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9857 - accuracy: 0.5000
# Epoch 15/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9630 - accuracy: 0.5200
# Epoch 16/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9414 - accuracy: 0.5200
# Epoch 17/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9212 - accuracy: 0.5000
# Epoch 18/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9022 - accuracy: 0.5400
# Epoch 19/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8821 - accuracy: 0.5600
# Epoch 20/40
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8646 - accuracy: 0.5800
# Epoch 21/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8421 - accuracy: 0.5400
# Epoch 22/40
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8209 - accuracy: 0.6000
# Epoch 23/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8037 - accuracy: 0.6200
# Epoch 24/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7834 - accuracy: 0.6200
# Epoch 25/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7599 - accuracy: 0.7200
# Epoch 26/40
# 2/2 [==============================] - 0s 3ms/step - loss: 1.7396 - accuracy: 0.7200
# Epoch 27/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7186 - accuracy: 0.7200
# Epoch 28/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6958 - accuracy: 0.7200
# Epoch 29/40
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6769 - accuracy: 0.7400
# Epoch 30/40
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6533 - accuracy: 0.6800
# Epoch 31/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6331 - accuracy: 0.7200
# Epoch 32/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6097 - accuracy: 0.7400
# Epoch 33/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5848 - accuracy: 0.7400
# Epoch 34/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5678 - accuracy: 0.7600
# Epoch 35/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5471 - accuracy: 0.8000
# Epoch 36/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5186 - accuracy: 0.8000
# Epoch 37/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4951 - accuracy: 0.8000
# Epoch 38/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4690 - accuracy: 0.8400
# Epoch 39/40
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4497 - accuracy: 0.8200
# Epoch 40/40
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4239 - accuracy: 0.8800
# end fit
# 594/594 [==============================] - 1s 1ms/step - loss: 2.0025 - accuracy: 0.3550
# Test score for measure 50 loss: 2.00246000289917
# Test score for measure 50 accuracy: 0.35499998927116394
# 313/313 [==============================] - 0s 1ms/step - loss: 2.0067 - accuracy: 0.3574
# Validation score for measure 50 loss: 2.006669044494629
# Validation score for measure 50 accuracy: 0.35740000009536743
# start fit
# Epoch 1/40
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3989 - accuracy: 0.0800
# Epoch 2/40
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3108 - accuracy: 0.0800
# Epoch 3/40
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2247 - accuracy: 0.1400
# Epoch 4/40
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1670 - accuracy: 0.1800
# Epoch 5/40
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1162 - accuracy: 0.2200
# Epoch 6/40
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0585 - accuracy: 0.3400
# Epoch 7/40
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0136 - accuracy: 0.3800
# Epoch 8/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9678 - accuracy: 0.4500
# Epoch 9/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9185 - accuracy: 0.4900
# Epoch 10/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8694 - accuracy: 0.5000
# Epoch 11/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8247 - accuracy: 0.5900
# Epoch 12/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7761 - accuracy: 0.5700
# Epoch 13/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7317 - accuracy: 0.6300
# Epoch 14/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6865 - accuracy: 0.6400
# Epoch 15/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6452 - accuracy: 0.6800
# Epoch 16/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5897 - accuracy: 0.7500
# Epoch 17/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5417 - accuracy: 0.7000
# Epoch 18/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4908 - accuracy: 0.8000
# Epoch 19/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4263 - accuracy: 0.8100
# Epoch 20/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3877 - accuracy: 0.7600
# Epoch 21/40
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3341 - accuracy: 0.7500
# Epoch 22/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2705 - accuracy: 0.8200
# Epoch 23/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2654 - accuracy: 0.7700
# Epoch 24/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2000 - accuracy: 0.8200
# Epoch 25/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1505 - accuracy: 0.8400
# Epoch 26/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1005 - accuracy: 0.8100
# Epoch 27/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0678 - accuracy: 0.8400
# Epoch 28/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0360 - accuracy: 0.8700
# Epoch 29/40
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0040 - accuracy: 0.9000
# Epoch 30/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9565 - accuracy: 0.9000
# Epoch 31/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9300 - accuracy: 0.8700
# Epoch 32/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8795 - accuracy: 0.9100
# Epoch 33/40
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8509 - accuracy: 0.8900
# Epoch 34/40
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8249 - accuracy: 0.9200
# Epoch 35/40
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8054 - accuracy: 0.8800
# Epoch 36/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7619 - accuracy: 0.8900
# Epoch 37/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7448 - accuracy: 0.9100
# Epoch 38/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7042 - accuracy: 0.8900
# Epoch 39/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.9100
# Epoch 40/40
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.8800
# end fit
# 594/594 [==============================] - 1s 986us/step - loss: 1.4631 - accuracy: 0.5291
# Test score for measure 100 loss: 1.4631154537200928
# Test score for measure 100 accuracy: 0.5290526151657104
# 313/313 [==============================] - 0s 943us/step - loss: 1.4902 - accuracy: 0.5181
# Validation score for measure 100 loss: 1.4902452230453491
# Validation score for measure 100 accuracy: 0.5181000232696533
# 1000
# start fit
# Epoch 1/40
# 32/32 [==============================] - 0s 2ms/step - loss: 2.2909 - accuracy: 0.1690
# Epoch 2/40
# 32/32 [==============================] - 0s 1ms/step - loss: 2.1115 - accuracy: 0.3760
# Epoch 3/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.9517 - accuracy: 0.4890
# Epoch 4/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.7761 - accuracy: 0.5540
# Epoch 5/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.5931 - accuracy: 0.5950
# Epoch 6/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.4361 - accuracy: 0.6520
# Epoch 7/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.2989 - accuracy: 0.6690
# Epoch 8/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1968 - accuracy: 0.6900
# Epoch 9/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1151 - accuracy: 0.7200
# Epoch 10/40
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0474 - accuracy: 0.7240
# Epoch 11/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9931 - accuracy: 0.7440
# Epoch 12/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9402 - accuracy: 0.7600
# Epoch 13/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9073 - accuracy: 0.7550
# Epoch 14/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8676 - accuracy: 0.7730
# Epoch 15/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8328 - accuracy: 0.7720
# Epoch 16/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8054 - accuracy: 0.7830
# Epoch 17/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7754 - accuracy: 0.7950
# Epoch 18/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7502 - accuracy: 0.8040
# Epoch 19/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7296 - accuracy: 0.8090
# Epoch 20/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6979 - accuracy: 0.8160
# Epoch 21/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6773 - accuracy: 0.8200
# Epoch 22/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6598 - accuracy: 0.8200
# Epoch 23/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6313 - accuracy: 0.8400
# Epoch 24/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6198 - accuracy: 0.8360
# Epoch 25/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6090 - accuracy: 0.8430
# Epoch 26/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.8430
# Epoch 27/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5669 - accuracy: 0.8510
# Epoch 28/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5522 - accuracy: 0.8560
# Epoch 29/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5288 - accuracy: 0.8630
# Epoch 30/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5145 - accuracy: 0.8680
# Epoch 31/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5121 - accuracy: 0.8650
# Epoch 32/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4917 - accuracy: 0.8710
# Epoch 33/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4775 - accuracy: 0.8780
# Epoch 34/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4611 - accuracy: 0.8800
# Epoch 35/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4470 - accuracy: 0.8900
# Epoch 36/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4384 - accuracy: 0.8900
# Epoch 37/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4204 - accuracy: 0.8910
# Epoch 38/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4180 - accuracy: 0.8920
# Epoch 39/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4017 - accuracy: 0.9010
# Epoch 40/40
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3877 - accuracy: 0.9060
# end fit
# 594/594 [==============================] - 1s 996us/step - loss: 1.0013 - accuracy: 0.7291
# Test score for measure 1000 loss: 1.0013103485107422
# Test score for measure 1000 accuracy: 0.7290526032447815
# 313/313 [==============================] - 0s 977us/step - loss: 1.0200 - accuracy: 0.7210
# Validation score for measure 1000 loss: 1.0199636220932007
# Validation score for measure 1000 accuracy: 0.7210000157356262
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# start fit
# Epoch 1/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.9122 - accuracy: 0.7440
# Epoch 2/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.6642 - accuracy: 0.8056
# Epoch 3/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.6091 - accuracy: 0.8190
# Epoch 4/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.5758 - accuracy: 0.8273
# Epoch 5/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.5488 - accuracy: 0.8355
# Epoch 6/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.5265 - accuracy: 0.8417
# Epoch 7/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.5056 - accuracy: 0.8474
# Epoch 8/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.4863 - accuracy: 0.8524
# Epoch 9/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.4680 - accuracy: 0.8581
# Epoch 10/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.4524 - accuracy: 0.8625
# Epoch 11/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.4367 - accuracy: 0.8681
# Epoch 12/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.4225 - accuracy: 0.8706
# Epoch 13/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.4075 - accuracy: 0.8747
# Epoch 14/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.3938 - accuracy: 0.8788
# Epoch 15/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.3822 - accuracy: 0.8823
# Epoch 16/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.3696 - accuracy: 0.8868
# Epoch 17/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.3579 - accuracy: 0.8903
# Epoch 18/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3479 - accuracy: 0.8924
# Epoch 19/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.3368 - accuracy: 0.8967
# Epoch 20/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.3263 - accuracy: 0.8991
# Epoch 21/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3166 - accuracy: 0.9030
# Epoch 22/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3052 - accuracy: 0.9063
# Epoch 23/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2954 - accuracy: 0.9094
# Epoch 24/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.2865 - accuracy: 0.9130
# Epoch 25/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.2773 - accuracy: 0.9159
# Epoch 26/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2674 - accuracy: 0.9182
# Epoch 27/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2593 - accuracy: 0.9206
# Epoch 28/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2492 - accuracy: 0.9237
# Epoch 29/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2412 - accuracy: 0.9265
# Epoch 30/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.2333 - accuracy: 0.9293
# Epoch 31/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2257 - accuracy: 0.9314
# Epoch 32/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.2172 - accuracy: 0.9342
# Epoch 33/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2092 - accuracy: 0.9362
# Epoch 34/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.2032 - accuracy: 0.9382
# Epoch 35/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1953 - accuracy: 0.9406
# Epoch 36/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.1874 - accuracy: 0.9439
# Epoch 37/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.1816 - accuracy: 0.9457
# Epoch 38/40
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.1750 - accuracy: 0.9464
# Epoch 39/40
# 1563/1563 [==============================] - 2s 2ms/step - loss: 0.1683 - accuracy: 0.9501
# Epoch 40/40
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1613 - accuracy: 0.9524
# end fit
# 594/594 [==============================] - 1s 1ms/step - loss: 0.7492 - accuracy: 0.8264
# Test score for measure 50000 loss: 0.7492420673370361
# Test score for measure 50000 accuracy: 0.8263683915138245
# 313/313 [==============================] - 0s 1ms/step - loss: 0.7603 - accuracy: 0.8194
# Validation score for measure 50000 loss: 0.7602905035018921
# Validation score for measure 50000 accuracy: 0.8194000124931335
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# start fit
# Epoch 1/40
# 6250/6250 [==============================] - 12s 2ms/step - loss: 0.7130 - accuracy: 0.7934
# Epoch 2/40
# 6250/6250 [==============================] - 10s 2ms/step - loss: 0.5547 - accuracy: 0.8336
# Epoch 3/40
# 6250/6250 [==============================] - 10s 2ms/step - loss: 0.5045 - accuracy: 0.8474
# Epoch 4/40
# 6250/6250 [==============================] - 11s 2ms/step - loss: 0.4707 - accuracy: 0.8571
# Epoch 5/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.4455 - accuracy: 0.8654
# Epoch 6/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.4251 - accuracy: 0.8703
# Epoch 7/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.4089 - accuracy: 0.8755
# Epoch 8/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3947 - accuracy: 0.8796
# Epoch 9/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3823 - accuracy: 0.8828
# Epoch 10/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3707 - accuracy: 0.8861
# Epoch 11/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3600 - accuracy: 0.8884
# Epoch 12/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3505 - accuracy: 0.8920
# Epoch 13/40
# 6250/6250 [==============================] - 10s 2ms/step - loss: 0.3417 - accuracy: 0.8947
# Epoch 14/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3337 - accuracy: 0.8968
# Epoch 15/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3257 - accuracy: 0.8991
# Epoch 16/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3181 - accuracy: 0.9014
# Epoch 17/40
# 6250/6250 [==============================] - 9s 2ms/step - loss: 0.3115 - accuracy: 0.9029
# Epoch 18/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.3047 - accuracy: 0.9053
# Epoch 19/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2985 - accuracy: 0.9073
# Epoch 20/40
# 6250/6250 [==============================] - 9s 2ms/step - loss: 0.2931 - accuracy: 0.9087
# Epoch 21/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2874 - accuracy: 0.9105
# Epoch 22/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2820 - accuracy: 0.9119
# Epoch 23/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2769 - accuracy: 0.9133
# Epoch 24/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2710 - accuracy: 0.9152
# Epoch 25/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2663 - accuracy: 0.9170
# Epoch 26/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2609 - accuracy: 0.9180
# Epoch 27/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2568 - accuracy: 0.9194
# Epoch 28/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2520 - accuracy: 0.9207
# Epoch 29/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2478 - accuracy: 0.9220
# Epoch 30/40
# 6250/6250 [==============================] - 11s 2ms/step - loss: 0.2439 - accuracy: 0.9233
# Epoch 31/40
# 6250/6250 [==============================] - 19s 3ms/step - loss: 0.2396 - accuracy: 0.9246
# Epoch 32/40
# 6250/6250 [==============================] - 13s 2ms/step - loss: 0.2350 - accuracy: 0.9259
# Epoch 33/40
# 6250/6250 [==============================] - 16s 3ms/step - loss: 0.2310 - accuracy: 0.9272
# Epoch 34/40
# 6250/6250 [==============================] - 19s 3ms/step - loss: 0.2274 - accuracy: 0.9289
# Epoch 35/40
# 6250/6250 [==============================] - 12s 2ms/step - loss: 0.2235 - accuracy: 0.9296
# Epoch 36/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2200 - accuracy: 0.9311
# Epoch 37/40
# 6250/6250 [==============================] - 9s 1ms/step - loss: 0.2164 - accuracy: 0.9323
# Epoch 38/40
# 6250/6250 [==============================] - 11s 2ms/step - loss: 0.2129 - accuracy: 0.9331
# Epoch 39/40
# 6250/6250 [==============================] - 12s 2ms/step - loss: 0.2092 - accuracy: 0.9341
# Epoch 40/40
# 6250/6250 [==============================] - 10s 2ms/step - loss: 0.2064 - accuracy: 0.9351
# end fit
# 594/594 [==============================] - 1s 1ms/step - loss: 0.4875 - accuracy: 0.8736
# Test score for measure 200000 loss: 0.48754221200942993
# Test score for measure 200000 accuracy: 0.8736315965652466
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.8756
# Validation score for measure 200000 loss: 0.48769286274909973
# Validation score for measure 200000 accuracy: 0.8755999803543091

# %%
print(scores_test)
print(scores_val)
# Out:
# {50: 0.35499998927116394, 100: 0.5290526151657104, 1000: 0.7290526032447815, 50000: 0.8263683915138245, 200000: 0.8736315965652466}
# {50: 0.35740000009536743, 100: 0.5181000232696533, 1000: 0.7210000157356262, 50000: 0.8194000124931335, 200000: 0.8755999803543091}

# %%
lists = sorted(scores_test.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()
